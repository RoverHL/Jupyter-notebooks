# %% [markdown]
# ## Boston Gender with Python!!! and machine learning!!!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import csv
import numpy as np
import random
import scipy.stats as ss
import matplotlib.pyplot as plt

# %%
#from https://pypi.python.org/pypi/gender-guesser/0.4.0
#uses python 3 

import gender_guesser.detector as gender
d = gender.Detector()
print(d.get_gender(u"Bob"))

print(d.get_gender(u"Sally"))

print(d.get_gender(u"Pauley")) # should be androgynous
# Out:
# male
# female
# andy

# %%
#import the csv i downloaded from the website with the names -- could robotize this later..
# they have an API https://data.cityofboston.gov/Finance/Employee-Earnings-Report-2015/ah28-sywy
pay_2016 = pd.read_csv("Employee_Earnings_Report_2016.csv")

#pay_2015 = pd.read_csv("Employee_Earnings_Report_2015.csv")
#pay_2014 = pd.read_csv("Employee_Earnings_Report_2014.csv")
#pay_2016.head()

# %%
#ay_2016.info()
#pay_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21902 entries, 0 to 21901
# Data columns (total 12 columns):
# NAME                         21902 non-null object
# DEPARTMENT_NAME              21902 non-null object
# TITLE                        21902 non-null object
# REGULAR                      21902 non-null object
# RETRO                        21902 non-null object
# OTHER                        21902 non-null object
# OVERTIME                     21902 non-null object
# INJURED                      21902 non-null object
# DETAILS                      21902 non-null object
# QUINN/EDUCATION INCENTIVE    21902 non-null object
# TOTAL EARNINGS               21902 non-null object
# POSTAL                       21900 non-null object
# dtypes: object(12)
# memory usage: 2.0+ MB

# %%
#pay_2014.head(10)
pay_2015.head(10)
# Out:
#                         NAME               DEPARTMENT_NAME  \
# 0             Abadi,Kidani A          Assessing Department
# 1           Abasciano,Joseph      Boston Police Department
# 2     Abban,Christopher John        Boston Fire Department
# 3    Abbate-Vaughn,Jorgelina          BPS Ellis Elementary
# 4           Abberton,James P       Public Works Department
# 5             Abbott,John R.  BPS Snowden International Hi
# 6           Abbruzzese,Donna           BPS Clap Elementary
# 7      Abdalkhallaq,Amira N.           BPS O'Bryant School
# 8  Abdal-Khallaq,Musiri Kari                 Green Academy
# 9        Abdal-Khallaq,Naima          BPS Charlestown High
#
#                       TITLE     REGULAR  RETRO     OTHER   OVERTIME  \
# 0          Property Officer   $44006.26  $0.00   $275.00    $324.12
# 1            Police Officer    $-886.20  $0.00  $8088.35    $544.83
# 2              Fire Fighter  $101468.29  $0.00   $550.00  $15146.51
# 3                   Teacher   $42919.31  $0.00     $0.00      $0.00
# 4  Maint Mech (Carpenter)##   $39768.17  $0.00   $126.00  $13974.97
# 5                   Teacher   $98938.55  $0.00     $0.00      $0.00
# 6       Lunch Hour Monitors    $8873.97  $0.00     $0.00      $0.00
# 7                   Teacher  $106848.84  $0.00   $340.00      $0.00
# 8                   Teacher   $84249.74  $0.00  $3712.28      $0.00
# 9                   Teacher   $88539.63  $0.00     $0.00      $0.00
#
#      INJURED   DETAILS QUINN/EDUCATION INCENTIVE TOTAL EARNINGS POSTAL
# 0      $0.00     $0.00                     $0.00      $44605.38  02118
# 1  $81996.78     $0.00                 $20667.80     $110411.56  02132
# 2      $0.00  $5168.00                     $0.00     $122332.80  02132
# 3      $0.00     $0.00                     $0.00      $42919.31  02481
# 4      $0.00     $0.00                     $0.00      $53869.14  02127
# 5      $0.00     $0.00                     $0.00      $98938.55  02445
# 6      $0.00     $0.00                     $0.00       $8873.97  02125
# 7      $0.00     $0.00                     $0.00     $107188.84  02121
# 8      $0.00     $0.00                     $0.00      $87962.02  02119
# 9      $0.00     $0.00                     $0.00      $88539.63  02121

# %% [markdown]
# what would I like to do now? for the graphic, I need to genderize, and then pick the top 100 people by pay.
# the genderizer uses first name,so I need to make a column of first names..Ill start with the 2016 data set and aim to have this done soon to update my graphic...
# ...Ill have to experiment a bit with the genderizer so will pull out 20 names to test them..

# %%
#d_2016 = pay_2016 #copying the dataset to avoid changes
d_2015 = pay_2015
#d_2014 = pay_2014


#d_2016['regular'] = (d_2016['REGULAR'].replace( '[\$,)]','', regex=True ).astype(float))
#d_2016 = d_2016.rename(columns = {
#'REGULAR':"regular",
#"RETRO": "retro",})
                       
                       
#d_2016.head()
d_2015.head()
# Out:
#                       NAME           DEPARTMENT_NAME  \
# 0           Abadi,Kidani A      Assessing Department
# 1         Abasciano,Joseph  Boston Police Department
# 2   Abban,Christopher John    Boston Fire Department
# 3  Abbate-Vaughn,Jorgelina      BPS Ellis Elementary
# 4         Abberton,James P   Public Works Department
#
#                       TITLE     REGULAR  RETRO     OTHER   OVERTIME  \
# 0          Property Officer   $44006.26  $0.00   $275.00    $324.12
# 1            Police Officer    $-886.20  $0.00  $8088.35    $544.83
# 2              Fire Fighter  $101468.29  $0.00   $550.00  $15146.51
# 3                   Teacher   $42919.31  $0.00     $0.00      $0.00
# 4  Maint Mech (Carpenter)##   $39768.17  $0.00   $126.00  $13974.97
#
#      INJURED   DETAILS QUINN/EDUCATION INCENTIVE TOTAL EARNINGS POSTAL
# 0      $0.00     $0.00                     $0.00      $44605.38  02118
# 1  $81996.78     $0.00                 $20667.80     $110411.56  02132
# 2      $0.00  $5168.00                     $0.00     $122332.80  02132
# 3      $0.00     $0.00                     $0.00      $42919.31  02481
# 4      $0.00     $0.00                     $0.00      $53869.14  02127

# %%
#do I need to make sure other stuff is string?

d_2015['REGULAR'] = (d_2015['REGULAR'].replace( '[\$,)]','', regex=True ).astype(float)).round()
d_2015['RETRO'] = (d_2015['RETRO'].replace( '[\$,)]','', regex=True ).astype(float)).round()
d_2015['OTHER'] = (d_2015['OTHER'].replace( '[\$,)]','', regex=True ).astype(float)).round()
d_2015['OVERTIME'] = (d_2015['OVERTIME'].replace( '[\$,)]','', regex=True ).astype(float)).round()
d_2015['INJURED'] = (d_2015['INJURED'].replace( '[\$,)]','', regex=True ).astype(float)).round()
#in 2015 its detailS vs 2016 detail 
d_2015['DETAILS'] = (d_2015['DETAILS'].replace( '[\$,)]','', regex=True ).astype(float)).round()
d_2015['QUINN/EDUCATION INCENTIVE'] = (d_2015['QUINN/EDUCATION INCENTIVE'].replace( '[\$,)]','', regex=True ).astype(float)).round()
d_2015['TOTAL EARNINGS'] = (d_2015['TOTAL EARNINGS'].replace( '[\$,)]','', regex=True ).astype(float)).round()


d_2015.head()

d_2015 = d_2015.rename(columns = {
'REGULAR':"salary",
'RETRO':"retroactive",
'OTHER':'other',
'OVERTIME':'overtime',
'DETAIL':'detail',
'INJURED':'injured',
'QUINN/EDUCATION INCENTIVE':'quinn_education_incentive',
'TOTAL EARNINGS':'totalSalary',
'NAME':'name',
"DEPARTMENT_NAME" : "dept",
"TITLE" : "title",
"POSTAL" : "zip_code",
    
    
})
d_2015.head()


#the csv used for d3(v3) jsI want to update has this: columns are name, 
#firstName, dept, salary, totalSalary(still has $), gender -- is just F or M
# Out:
#                       name                      dept  \
# 0           Abadi,Kidani A      Assessing Department
# 1         Abasciano,Joseph  Boston Police Department
# 2   Abban,Christopher John    Boston Fire Department
# 3  Abbate-Vaughn,Jorgelina      BPS Ellis Elementary
# 4         Abberton,James P   Public Works Department
#
#                       title    salary  retroactive   other  overtime  injured  \
# 0          Property Officer   44006.0          0.0   275.0     324.0      0.0
# 1            Police Officer    -886.0          0.0  8088.0     545.0  81997.0
# 2              Fire Fighter  101468.0          0.0   550.0   15147.0      0.0
# 3                   Teacher   42919.0          0.0     0.0       0.0      0.0
# 4  Maint Mech (Carpenter)##   39768.0          0.0   126.0   13975.0      0.0
#
#    DETAILS  quinn_education_incentive  totalSalary zip_code
# 0      0.0                        0.0      44605.0    02118
# 1      0.0                    20668.0     110412.0    02132
# 2   5168.0                        0.0     122333.0    02132
# 3      0.0                        0.0      42919.0    02481
# 4      0.0                        0.0      53869.0    02127

# %% [markdown]
# Round salaries to nearest dollar

# %%
import math
h = int(round(4.2))
h
# Out:
# 4

# %% [markdown]
# ### I ll split on the names
# and now can see that there are some middle names
# so I'm going to use Regex to clean a bit..
# if there is a Capitalized letter with nothing after, or a capitalized letter with a period, I want to split it, but otherwise Ill keep the two names, don't know how genderizer will handle them but well see..

# %% [markdown]
# had to do the splitting off of first name in two steps that probably should be one so can review later..below might help
#
# #see this
# #https://stackoverflow.com/questions/29585106/pandas-how-to-split-twice-a-given-field
#  #try this:
# trimmed_list = [i.replace('.', ',').split(',') for i in sbj[0].tolist() if i != ""]
# item_list = [item.strip(whitespace) for item in itertools.chain(*trimmed_list)]
# item_count = Counter(item_list)

# %%
firstName = d_2015.name.apply(lambda x: x.split(',')[1])
y = [name.split(" ")[0] for name in firstName]
y
#[]f_name.apply(lambda x: x.split(',')[1])
#first_name

#name_split = [name.split(',') for name in names]
#newlist = []
#for name in name_split:
 #   first = name[1]
  #  newlist.append(first)
#y = []
#for name in f_name:
 #   x = name.split(" ")
  #  y.append(x[0])
#print(y)
# Out:
# ['Kidani',
#  'Joseph',
#  'Christopher',
#  'Jorgelina',
#  'James',
#  'John',
#  'Donna',
#  'Amira',
#  'Musiri',
#  'Naima',
#  'Lisa',
#  'Maha',
#  'Ramadani',
#  'Ahmad',
#  'Theodora',
#  'Imelda',
#  'Jean',
#  'Eliphete',
#  'Marc',
#  'Linda',
#  'Obaida',
#  'Jocelyne',
#  'Randolph',
#  'Sharon',
#  'Patrick',
#  'Daniel',
#  'Harriet',
#  'Genoveva',
#  'Cesar',
#  'Iris',
#  'Julie',
#  'Miguel',
#  'Moises',
#  'Ramona',
#  'Wayne',
#  'Nicolina',
#  'Farouqua',
#  'Patricia',
#  'Jean',
#  'Marie',
#  'AnnMarie',
#  'William',
#  'Richard',
#  'Blanca',
#  'Dora',
#  'Jasmine',
#  'Rafael',
#  'Ricardo',
#  'Terisa',
#  'Ilana',
#  'Lodz',
#  'Geoffrey',
#  'Lyn',
#  'Jean',
#  'Christopher',
#  'Ariel',
#  'Carina',
#  'Jose',
#  'Tanya',
#  'Robert',
#  'Jessica',
#  'S.Farhan',
#  'Donna',
#  'Nicole',
#  'Carey',
#  'Christopher',
#  'Christopher',
#  'Clyde',
#  'Daniel',
#  'Daune',
#  'Duel',
#  'Eleanor',
#  'Elizabeth',
#  'Frederick',
#  'Heather',
#  'Jasenta',
#  'John',
#  'Kwame',
#  'Lateisha',
#  'Lucille',
#  'Natasha',
#  'Paul',
#  'Rebecca',
#  'Terrence',
#  'Leslie',
#  'Aileen',
#  'Jamal',
#  'Anthony',
#  'Evelyn',
#  'David',
#  'Fatima',
#  'Kadra',
#  'Rocco',
#  'John',
#  'Joseph',
#  'Vincent',
#  'Elizabeth',
#  'Adebayo',
#  'John',
#  'Loraine',
#  'AnnMarie',
#  'Attah',
#  'David',
#  'Robert',
#  'Maxwell',
#  'Christine',
#  'Gloria',
#  'Marie',
#  'Dalia',
#  'Emmanuel',
#  'Sameer',
#  'Adelina',
#  'Michael',
#  'Mavrick',
#  'Eleni',
#  'Laverne',
#  'Darius',
#  'Sharon',
#  'Olajumoke',
#  'Ellen',
#  'Maritza',
#  'Hingel',
#  'Cinthia',
#  'Deborah',
#  'Juan',
#  'Luis',
#  'Maria',
#  'Rosalind',
#  'Allison',
#  'Frances',
#  'Sean',
#  'Fred',
#  'David',
#  'Denise',
#  'Elizabeth',
#  'Gerard',
#  'Jessica',
#  'John',
#  'John',
#  'Julianne',
#  'Kelly',
#  'Michael',
#  'Waliah',
#  'Abdirashid',
#  'Said',
#  'Kriss',
#  'Jaclyn',
#  'Kirkland',
#  'Catherine',
#  'Laura',
#  'Brandon',
#  'Archana',
#  'Ulana',
#  'Donna',
#  'Nathalie',
#  'Gerald',
#  'Natalie',
#  'Robert',
#  'Gary',
#  'Tinu',
#  'Dru',
#  'Valerie',
#  'Gerard',
#  'Jason',
#  'Mary',
#  'Matthew',
#  'Matthew',
#  'Anthony',
#  'Caitlyn',
#  'Julianne',
#  'Andrea',
#  'Brian',
#  'Jesse',
#  'Thelma',
#  'Virginia',
#  'Lauren',
#  'Jessie',
#  'Thomas',
#  'Debora',
#  'Sonia',
#  'Carene',
#  'Wilda',
#  'Alba',
#  'Monika',
#  'Jennifer',
#  'John',
#  'Kathleen',
#  'Kathryn',
#  'Meghan',
#  'Jacqueline',
#  'Juan',
#  'Adrian',
#  'Maria',
#  'Wilson',
#  'Neville',
#  'Wendy',
#  'Dennis',
#  'John',
#  'Bruce',
#  'George',
#  'Cassandra',
#  'Joshua',
#  'Khari',
#  'Lauren',
#  'Marvella',
#  'Marvin',
#  'Mervyn',
#  'Valerie',
#  'J.',
#  'Ricardo',
#  'Yves',
#  'Amanda',
#  'Anthony',
#  'Caroline',
#  'Carolle',
#  'Fransnor',
#  'Jeffrey',
#  'Mirlene',
#  'Patrick',
#  'Ronel',
#  'Roy',
#  'Sarah',
#  'Silvia',
#  'Aaron',
#  'Frank',
#  'Juana',
#  'Thomas',
#  'Georgina',
#  'Jose',
#  'Lirida',
#  'Sherika',
#  'Abdi',
#  'Ahmed',
#  'Amelia',
#  'Andrei',
#  'Halima',
#  'Idris',
#  'Omar',
#  'Betsy',
#  'Gilbert',
#  'Hector',
#  'Hector',
#  'Kenneth',
#  'Margarita',
#  'Mary',
#  'Omaira',
#  'Ramon',
#  'James',
#  'Brian',
#  'Jeffrey',
#  'Joanne',
#  'Brett',
#  'Vanessa',
#  'Darlene',
#  'Alexander',
#  'Alston',
#  'Navarra',
#  'Amani',
#  'Christopher',
#  'Corey',
#  'Debra',
#  'Denis',
#  'Derek',
#  'Erica',
#  'Frederick',
#  'Geneva',
#  'Glenroy',
#  'Gregory',
#  'Henry',
#  'Ike',
#  'Justin',
#  'Katherine',
#  'Katherine',
#  'Keith',
#  'Melanie',
#  'Nakysha',
#  'Nancy',
#  'R',
#  'Sharron',
#  'Shiaka',
#  'Stephanie',
#  'Tyler',
#  'Tyler',
#  'Vandon',
#  'William',
#  'Robert',
#  'Deborah',
#  'Wesley',
#  'Danielle',
#  'Haley',
#  'Karima',
#  'Bartley',
#  'John',
#  'Andrea',
#  'Helen',
#  'Michelle',
#  'Michelle',
#  'Carolyn',
#  'Ruth',
#  'Michael',
#  'Maria',
#  'Cristina',
#  'Nadia',
#  'Ana',
#  'Crystal',
#  'Earl',
#  'Ernestina',
#  'Ismael',
#  'Silas',
#  'Alexis',
#  'Carlos',
#  'Adriana',
#  'Gabriel',
#  'Iris',
#  'Silvia',
#  'Kareen',
#  'Helsa',
#  'April',
#  'Diane',
#  'Jennifer',
#  'Scott',
#  'Josue',
#  'Shalia',
#  'Jean',
#  'Clyde',
#  'Aaron',
#  'Carrie',
#  'Mai',
#  'Ada',
#  'Alyssa',
#  'Diego',
#  'Edna',
#  'Florentin',
#  'Lissette',
#  'Migdalia',
#  'Tanairy',
#  'Marilu',
#  'Evelyn',
#  'Alex',
#  'Amy',
#  'Audwin',
#  'Carmen',
#  'Christopher',
#  'Edwin',
#  'Hector',
#  'Hugo',
#  'Indira',
#  'Ivon',
#  'Lyndsey',
#  'Maritza',
#  'Merenciano',
#  'Nadine',
#  'Solimar',
#  'Wanda',
#  'Melvin',
#  'Manuel',
#  'Amaryah',
#  'Chantei',
#  'Chantel',
#  'Estefania',
#  'John',
#  'John',
#  'Manuel',
#  'Renee',
#  'Andrea',
#  'Carol',
#  'Damaris',
#  'Iolanda',
#  'Joe',
#  'Jose',
#  'Andria',
#  'Santa',
#  'Darnisa',
#  'Rachael',
#  'Mary',
#  'Frances',
#  'Luca',
#  'Paul',
#  'Philip',
#  'Deborah',
#  'Ruth',
#  'Allison',
#  'Diane',
#  'Robin',
#  'Vivian',
#  'Ana',
#  'Jose',
#  'Pascale',
#  'Michelle',
#  'Michel',
#  'Teresa',
#  'Larissa',
#  'June',
#  'Irene',
#  'Jennifer',
#  'Carl',
#  'Maria',
#  'Hind',
#  'Zoraida',
#  'Valerie',
#  'Jimmie',
#  'Elizabeth',
#  'Evelyn',
#  'Ralph',
#  'Rita',
#  'Nicole',
#  'Candida',
#  'Santa',
#  'Maria',
#  'Christine',
#  'Theodore',
#  'George',
#  'Oscar',
#  'Daniel',
#  'Belinda',
#  'Hugues',
#  'Barry',
#  'Lawrence',
#  'Erik',
#  'Robert',
#  'Benjamin',
#  'Candice',
#  'Christine',
#  'Cory',
#  'Daniel',
#  'Deirdre',
#  'Dorothy',
#  'Dulcie',
#  'Edward',
#  'Edward',
#  'Emma',
#  'Erik',
#  'Erin',
#  'Frederick',
#  'Heather',
#  'Jason',
#  'Jennifer',
#  'Jessica',
#  'Kerri',
#  'Lamont',
#  'Lauren',
#  'Leahna',
#  'Marcus',
#  'Matthew',
#  'Maureen',
#  'Nancy',
#  'Patricia',
#  'Robert',
#  'Robert',
#  'Rosemary',
#  'Shandolyn',
#  'Steven',
#  'Tamara',
#  'Taraneisha',
#  'Tim',
#  'Tina',
#  'Tracey',
#  'Donna-Marie',
#  'Stanley',
#  'Michelle',
#  'Patrick',
#  'Angel',
#  'Jody',
#  'Adalgisa',
#  'Aderito',
#  'Ana',
#  'Domingo',
#  'Ernestine',
#  'Eunice',
#  'Evelyn',
#  'Frank',
#  'Iuri',
#  'Jamie',
#  'Joao',
#  'Kim',
#  'Kimberly',
#  'Manuel',
#  'Manuela',
#  'Elitane',
#  'Marie',
#  'Matthew',
#  'Michael',
#  'Michael',
#  'Michelle',
#  'Michelle',
#  'Nylton',
#  'Regan',
#  'Richard',
#  'Sharon',
#  'Carmen',
#  'Nicholas',
#  'Lucie',
#  'Alfredo',
#  'Erica',
#  'Arreen',
#  'Prema',
#  'Malcolm',
#  'Atiba',
#  'Chinelle',
#  'Doreen',
#  'Heather',
#  'Helen',
#  'Jasmine',
#  'Jennifer',
#  'Kelley',
#  'Madeleine',
#  'Melissa',
#  'Michael',
#  'Phillip',
#  'William',
#  'Lina',
#  'Manuel',
#  'Nidia',
#  'Belkys',
#  'Elizabeth',
#  'Peter',
#  'Brent',
#  'Marco',
#  'Anna',
#  'Melissa',
#  'Cindy',
#  'Beryl',
#  'Robert',
#  'Katherine',
#  'Adie',
#  'Maria',
#  'Luis',
#  'Robert',
#  'Bradley',
#  'Jean-Dominique',
#  'Elaine',
#  'Sara',
#  'Loreto',
#  'Jennifer',
#  'Marie',
#  'Robert',
#  'Terrymore',
#  'Jean',
#  'Mathew',
#  'Smaralda',
#  'Jennifer',
#  'Lisa',
#  'Patricia',
#  'Mary',
#  'Thomas',
#  'John',
#  'Robyn',
#  'Susan',
#  'Joaquim',
#  'Leylah',
#  'Rafael',
#  'Janine',
#  'Gladys',
#  'Amanda',
#  'Maria',
#  'Carlos',
#  'Jennifer',
#  'Julie',
#  'Mercedes',
#  'Pablo',
#  'Pedro',
#  'Timothy',
#  'Walter',
#  'Susan',
#  'Pamela',
#  'Paul',
#  'Ronald',
#  'Henry',
#  'Carla',
#  'Carolina',
#  'Susan',
#  'Antonio',
#  'Celio',
#  'Christine',
#  'Claudia',
#  'Diamantino',
#  'Jose',
#  'Luis',
#  'Michelle',
#  'Nancy',
#  'Zaida',
#  'Malga-Belan',
#  'Rebecca',
#  'Patricia',
#  'Al',
#  'Marie',
#  'Gloria',
#  'Jillian',
#  'Sandra',
#  'Cynthia',
#  'Jean',
#  'Diane',
#  'Juan',
#  'Rebecca',
#  'Emily',
#  'Louis',
#  'Ellen',
#  'Yesica',
#  'Hilsia',
#  'Jose',
#  'Veronica',
#  'Kevin',
#  'Luz',
#  'Marlene',
#  'Flormarina',
#  'David',
#  'Dorothy',
#  'Jeffrey',
#  'Nicholas',
#  'Marie',
#  'Myriam',
#  'Deborah',
#  'John',
#  'Margaret',
#  'Michael',
#  'Malica',
#  'Jane',
#  'Joshua',
#  'Amanda',
#  'Brian',
#  'Kathleen',
#  'Lorrie',
#  'Martina',
#  'Catherine',
#  'James',
#  'Jason',
#  'Karen',
#  'Rodney',
#  'Spencer',
#  'Walter',
#  'Krishante',
#  'Anne',
#  'Patsy',
#  'Eric',
#  'Alan',
#  'Jacquelyne',
#  'Lorellys',
#  'Norma',
#  'Ana',
#  'Felix',
#  'Jamie',
#  'Leida',
#  'Luis',
#  'Patricia',
#  'Ramona',
#  'Sonia',
#  'Zilma',
#  'David',
#  'Raymond',
#  'Kirsten',
#  'Lynn',
#  'Nancy',
#  'Patricia',
#  'Ryan',
#  'Matthew',
#  'Jasenka',
#  'Lillian',
#  'Nicholas',
#  'Gregory',
#  'Brandon',
#  'Darnell',
#  'Valarie',
#  'Lizzete',
#  'Donna',
#  'Ines',
#  'Antonio',
#  'Marcie',
#  'Sandra',
#  'Mojisola',
#  'Michael',
#  'Matthew',
#  'Nannette',
#  'Ann',
#  'Cheryl',
#  'Melvin',
#  'Ronald',
#  'Steven',
#  'Hala',
#  'Nilo',
#  'Susan',
#  'Quitina',
#  'Brian',
#  'Nathaniel',
#  'Wail',
#  'Margaret',
#  'Mark',
#  'Valerie',
#  'Farah',
#  'Robert',
#  'Rose',
#  'MIchael',
#  'Richard',
#  'Devin',
#  'Sean',
#  'Angela',
#  'Alville',
#  'Panagiota',
#  'Julius',
#  'Michael',
#  'Steven',
#  'Susan',
#  'Elaine',
#  'Patricia',
#  'Teresa',
#  'Katharine',
#  'Roseann',
#  'Marie',
#  'Erin',
#  'SiuYing',
#  'Maudeline',
#  'Shaina',
#  'Jennifer',
#  'Leslye',
#  'Richard',
#  'Danielle',
#  'Deicy',
#  'Gerda',
#  'Eleanor',
#  'Jessie',
#  'Gloria',
#  'Scott',
#  'Heralda',
#  'Melissa',
#  'Micheline',
#  'Renald',
#  'Woodley',
#  'Jean',
#  'St',
#  'Mildred',
#  'Ann',
#  'Claudette',
#  'Eleanor',
#  'Kenneth',
#  'Kenneth',
#  'Paul',
#  'Shamina',
#  'William',
#  'Gloria',
#  'Kenneth',
#  'Valerie',
#  'Elizabeth',
#  'Katharine',
#  'Neema',
#  'Concetta',
#  'Stephen',
#  'Charles',
#  'Christopher',
#  'Dawn',
#  'Perry',
#  'Eddy',
#  'Christine',
#  'Dennis',
#  'Jessica',
#  'Julio',
#  'Marta',
#  'Aaron',
#  'Alice',
#  'Carmen',
#  'Christopher',
#  'Debra',
#  'Elvin',
#  'Lucas',
#  'Aric',
#  'Elsa',
#  'Rami',
#  'Dawit',
#  'Musa',
#  'Ayodeji',
#  'Adelbowale',
#  'Anita',
#  'Norma',
#  'Arlene',
#  'Carmen',
#  'Guillermina',
#  'Jeannete',
#  'Maria',
#  'Meghan',
#  'Steven',
#  'Lawrence',
#  'Carol',
#  'Joan',
#  'Karen',
#  'Michael',
#  'Michael',
#  'Adesola',
#  'Eniolami',
#  'Helene',
#  'Dinesh',
#  'Rima',
#  'Richard',
#  'Clifford',
#  'Geraldine',
#  'Michael',
#  'Sheila',
#  'Rkia',
#  'Anochie',
#  'Jacqueline',
#  'Gillie',
#  'Philip',
#  'Tony',
#  'Theresa',
#  'Phanenca',
#  'Yasmine',
#  'Alan',
#  'Joseph',
#  'Laurinda',
#  'Margaret',
#  'Kenneth',
#  'Kenneth',
#  'Rakeem',
#  'Julia',
#  'Rosa',
#  'Barbara',
#  'William',
#  'Rafael',
#  'Altagracia',
#  'Alberto',
#  'Katherine',
#  'Lisbania',
#  'Makeurys',
#  'William',
#  'Katie-Nicole',
#  'Leah',
#  'Elisa',
#  'Joseph',
#  'Camden',
#  'Jamilee',
#  'Nicole',
#  'George',
#  'Carolyn',
#  'Todd',
#  'Ardena',
#  'Brenda',
#  'Casey',
#  'Christopher',
#  'Gerard',
#  'Jacqueline',
#  'John',
#  'Jossie',
#  'Kevin',
#  'Lita',
#  'Mary',
#  'Michelle',
#  'Nasha-Lee',
#  'Noel',
#  'Pamelia',
#  'Suzanne',
#  'Natasha',
#  'Patricia',
#  'Robert',
#  'Tasha',
#  'Alphonso',
#  'Amelie',
#  'Ayanna',
#  'Breton',
#  'Christopher',
#  'Elizabeth',
#  'Elizabeth',
#  'Francis',
#  'Francis',
#  'Jill',
#  'Katherine',
#  'Marva',
#  'Megan',
#  'Michael',
#  'Nancy',
#  'Rachel',
#  'Richard',
#  'Scott',
#  'Seth',
#  'Tamara',
#  'Tamika',
#  'Tosha',
#  'Catherine',
#  'Karyn',
#  'Amanda',
#  'Mary',
#  'Peter',
#  'Arturo',
#  'Lisa',
#  'Steven',
#  'Jessica',
#  'Andrew',
#  'Richard',
#  'Annie',
#  'Louis',
#  'Rane',
#  'Daiwattie',
#  'Reynold',
#  'Scott',
#  'Christina',
#  'Brian',
#  'John',
#  'MIchael',
#  'Susan',
#  'Thomas',
#  'Edward',
#  'Lucy',
#  'Quandell',
#  'Serena',
#  'Caroline',
#  'Jean',
#  'Jennifer',
#  'Aadina',
#  'Samuel',
#  'Nancy',
#  'Alana',
#  'Leah',
#  'Beatrice',
#  'Zucan',
#  'James',
#  'Marco',
#  'Jayashree',
#  'Sengova',
#  'Robert',
#  'Carla',
#  'Charles',
#  'Derrick',
#  'Eva',
#  'Gregory',
#  'James',
#  'Jeffrey',
#  'Kafunda',
#  'Kiel',
#  'Madeline',
#  'Nkrumah',
#  'Patricia',
#  'Pearlina',
#  'Crystal',
#  'Dominique',
#  'Diane',
#  'Kalvin',
#  'Sydney',
#  'Erin',
#  'Agnes',
#  'Paula',
#  'Malaquias',
#  'Evelyn',
#  'Jean',
#  'Deborah',
#  'Joan',
#  'Victoria',
#  'Rachael',
#  'Keith',
#  'Auta',
#  'Elsie',
#  'Isabel',
#  'Lisamarie',
#  'Magnusson',
#  'Maria',
#  'Steven',
#  'Jodi',
#  'Brian',
#  'Dorian',
#  'Dalton',
#  'Ellen',
#  'Michael',
#  'Philip',
#  'Robert',
#  'Sean',
#  'Sandra',
#  'Nathalie',
#  'Karen',
#  'William',
#  'Geri',
#  'Valerie',
#  'Blake',
#  'Ashley',
#  'Eric',
#  'Laura',
#  'Gary',
#  'Gary',
#  'Jillian',
#  'Marisa',
#  'Luke',
#  'Ascer',
#  'Marisa',
#  'Kay',
#  'Christopher',
#  'Dawn',
#  'Elaine',
#  'James',
#  'Kerry',
#  'Louis',
#  'Marlene',
#  'Traciana',
#  'Mercedees',
#  'Dwight',
#  'Jillian',
#  'Nancy',
#  'Laurie',
#  'Erin',
#  'Lisa',
#  'Antonine',
#  'Melanie',
#  'Michael',
#  'Micheka',
#  'Patrick',
#  'Robert',
#  'Lilian',
#  ...]

# %% [markdown]
# create a column called first name and one called gender

# %%
import gender_guesser.detector as gender
d = gender.Detector()

gender = []

for name in y:
    gender_it = d.get_gender(name)
    gender.append(gender_it)

d_2015["firstName"] = y
d_2015["gender"] = gender

# %% [markdown]
# Do the whole data set, create a column of first name and a column of gender, i need to make it match eventually
# what I used in my D3 csv to avoid hassle when recreating the graphic

# %%
d_2015.head()
# Out:
#                       name                      dept  \
# 0           Abadi,Kidani A      Assessing Department
# 1         Abasciano,Joseph  Boston Police Department
# 2   Abban,Christopher John    Boston Fire Department
# 3  Abbate-Vaughn,Jorgelina      BPS Ellis Elementary
# 4         Abberton,James P   Public Works Department
#
#                       title    salary  retroactive   other  overtime  injured  \
# 0          Property Officer   44006.0          0.0   275.0     324.0      0.0
# 1            Police Officer    -886.0          0.0  8088.0     545.0  81997.0
# 2              Fire Fighter  101468.0          0.0   550.0   15147.0      0.0
# 3                   Teacher   42919.0          0.0     0.0       0.0      0.0
# 4  Maint Mech (Carpenter)##   39768.0          0.0   126.0   13975.0      0.0
#
#    DETAILS  quinn_education_incentive  totalSalary zip_code    firstName  \
# 0      0.0                        0.0      44605.0    02118       Kidani
# 1      0.0                    20668.0     110412.0    02132       Joseph
# 2   5168.0                        0.0     122333.0    02132  Christopher
# 3      0.0                        0.0      42919.0    02481    Jorgelina
# 4      0.0                        0.0      53869.0    02127        James
#
#     gender
# 0  unknown
# 1     male
# 2     male
# 3  unknown
# 4     male

# %% [markdown]
# change the order of the columns

# %%
cols = list(d_2015.columns.values)
cols
# Out:
# ['name',
#  'dept',
#  'title',
#  'salary',
#  'retroactive',
#  'other',
#  'overtime',
#  'injured',
#  'DETAILS',
#  'quinn_education_incentive',
#  'totalSalary',
#  'zip_code',
#  'firstName',
#  'gender']

# %%
d_2015 = d_2015[[
 'name',
    'firstName',
 'gender',
 'salary',
    'totalSalary',
'dept',
 'title',
 'retroactive',
 'other',
 'overtime',
 'injured',
 'detail',
 'quinn_education_incentive',
 'zip_code', 
 ]]
d_2015.head()
# Out:
#                       name    firstName   gender    salary  totalSalary  \
# 0           Abadi,Kidani A       Kidani  unknown   46292.0      46592.0
# 1         Abasciano,Joseph       Joseph     male    6934.0      97580.0
# 2   Abban,Christopher John  Christopher     male  103442.0     124623.0
# 3            Abbasi,Sophia       Sophia   female   18250.0      18250.0
# 4  Abbate-Vaughn,Jorgelina    Jorgelina  unknown   84410.0      85660.0
#
#                        dept                 title  retroactive   other  \
# 0      Assessing Department      Property Officer          NaN   300.0
# 1  Boston Police Department        Police Officer          NaN   850.0
# 2    Boston Fire Department          Fire Fighter          NaN   550.0
# 3             Green Academy  Manager (C) (non-ac)          NaN     NaN
# 4      BPS Ellis Elementary               Teacher          NaN  1250.0
#
#    overtime  injured  detail  quinn_education_incentive zip_code
# 0       NaN      NaN     NaN                        NaN    02118
# 1     206.0  74332.0     NaN                    15258.0    02132
# 2   15885.0      NaN  4746.0                        NaN    02132
# 3       NaN      NaN     NaN                        NaN    02148
# 4       NaN      NaN     NaN                        NaN    02481

# %% [markdown]
# messing about with the name split
#
# name_split = [name.split(',') for name in names]
# newlist = []
# for name in name_split:
#     first = name[1]
#     newlist.append(first)
# y = []
# for name in newlist:
#     x = name.split(" ")
#     y.append(x[0])
#
# #add y as a column in the data set
#
# d_2016["first_names"] = y
# d_2016.head()

# %% [markdown]
# messing about
#
# import gender_guesser.detector as gender
# d = gender.Detector()
#
# gender = []
#
# for name in y:
#     gender_it = d.get_gender(name)
#     gender.append(gender_it)
# d_2016["gender"] = gender
# d_2016.head()

# %% [markdown]
# shortdf = d_2016[["NAME","first_names","gender","REGULAR"]] #I can add stuff here later and rerun for my csv, ie department
# print(shortdf.sort_values(by=['gender'],ascending=True))

# %% [markdown]
# now I'd like to see how many there are of each type in the new gender column...

# %%
d_2015['gender'].value_counts() #andy is androgynous
# Out:
# female           9240
# male             9060
# unknown          2062
# mostly_female     991
# mostly_male       378
# andy              171
# Name: gender, dtype: int64

# %% [markdown]
# df.loc[df['First Season'] > 1990, 'First Season'] = 1

# %%
d_2015.loc[d_2015['gender'] == "mostly_female", "gender"] = "female"
d_2015.loc[d_2015['gender'] == "mostly_male", "gender"] = "male"
d_2015['gender'].value_counts() #andy is androgynous
# Out:
# female     10231
# male        9438
# unknown     2062
# andy         171
# Name: gender, dtype: int64

# %% [markdown]
# I'm going to group mostly's into their respective groups

# %% [markdown]
# im going to sort by top 100 earners to see how many of those have different value counts since
# that's what I use in my chart

# %% [markdown]
# these two women are listed as unknowns, since I looked them up im going to fix in the data set..
# 13129          McCreary,Makeeba   Makeeba                 Communications
# 6050   Edouard-Vincent,Marice M    Marice  Asst Superintendent-Network A

# %%
d_2015.loc[d_2015['name'] == "McCreary,Makeeba", "gender"] = "female"
d_2015.loc[d_2015['name'] == "Edouard-Vincent,Marice M", "gender"] = "female"
d_2015['gender'].value_counts()
# Out:
# female     10233
# male        9438
# unknown     2060
# andy         171
# Name: gender, dtype: int64

# %%
d_2015.dtypes
# Out:
# name                          object
# dept                          object
# title                         object
# salary                       float64
# retroactive                  float64
# other                        float64
# overtime                     float64
# injured                      float64
# DETAILS                      float64
# quinn_education_incentive    float64
# totalSalary                  float64
# zip_code                      object
# firstName                     object
# gender                        object
# dtype: object

# %%
print(d_2015.shape)
d_2015.columns
# Out:
# (21902, 14)
# Index(['name', 'dept', 'title', 'salary', 'retroactive', 'other', 'overtime',
#        'injured', 'DETAILS', 'quinn_education_incentive', 'totalSalary',
#        'zip_code', 'firstName', 'gender'],
#       dtype='object')

# %%
d_2015.head()
# Out:
#                       name                      dept  \
# 0           Abadi,Kidani A      Assessing Department
# 1         Abasciano,Joseph  Boston Police Department
# 2   Abban,Christopher John    Boston Fire Department
# 3  Abbate-Vaughn,Jorgelina      BPS Ellis Elementary
# 4         Abberton,James P   Public Works Department
#
#                       title    salary  retroactive   other  overtime  injured  \
# 0          Property Officer   44006.0          0.0   275.0     324.0      0.0
# 1            Police Officer    -886.0          0.0  8088.0     545.0  81997.0
# 2              Fire Fighter  101468.0          0.0   550.0   15147.0      0.0
# 3                   Teacher   42919.0          0.0     0.0       0.0      0.0
# 4  Maint Mech (Carpenter)##   39768.0          0.0   126.0   13975.0      0.0
#
#    DETAILS  quinn_education_incentive  totalSalary zip_code    firstName  \
# 0      0.0                        0.0      44605.0    02118       Kidani
# 1      0.0                    20668.0     110412.0    02132       Joseph
# 2   5168.0                        0.0     122333.0    02132  Christopher
# 3      0.0                        0.0      42919.0    02481    Jorgelina
# 4      0.0                        0.0      53869.0    02127        James
#
#     gender
# 0  unknown
# 1     male
# 2     male
# 3  unknown
# 4     male

# %%
#Get a sense of how many missing values there are in the dataframe.
np.sum([d_2015.salary.isnull()])
np.sum([d_2015.gender.isnull()])
# Out:
# 0

# %%
salarySorted = d_2015.sort_values(by='salary', ascending=False)
salarySorted.head()
# Out:
#                         name                      dept  \
# 6894       Fontana,Gerard T.    Boston Fire Department
# 6571          Finn,Joseph E.    Boston Fire Department
# 6230         Evans,William B  Boston Police Department
# 20819     Walsh,John Francis    Boston Fire Department
# 8009   Granara,David Richard    Boston Fire Department
#
#                                 title    salary  retroactive    other  \
# 6894          Chief of Field Services  234578.0      21786.0  20625.0
# 6571   FCommissioner/Chief of theDept  212439.0          0.0      0.0
# 6230               Commissioner (Bpd)  207017.0          0.0      0.0
# 20819       Chief of Support Services  204893.0          0.0  12957.0
# 8009   DepFireChiefAdmn-AdvTechnician  201219.0          0.0  11818.0
#
#        overtime  injured  DETAILS  quinn_education_incentive  totalSalary  \
# 6894     8342.0   1545.0      0.0                        0.0     286876.0
# 6571        0.0      0.0      0.0                        0.0     212439.0
# 6230        0.0      0.0      0.0                        0.0     207017.0
# 20819    1730.0      0.0      0.0                        0.0     219580.0
# 8009     4578.0      0.0      0.0                        0.0     217615.0
#
#       zip_code firstName gender
# 6894     02169    Gerard   male
# 6571     02122    Joseph   male
# 6230     02127   William   male
# 20819    02184      John   male
# 8009     02128     David   male

# %% [markdown]
# so i have what i need above to export to csv and update my graph...START HERE
# -- after updating, play with bokeh here? do a new sheet to update FBI crime project?

# %% [markdown]
# the csv used for d3(v3) jsI want to update has this: columns are name, firstName, dept, salary, totalSalary(still has $), gender -- is just F or M
# so make a truncated version of the csv
# name in this style to be like existing csv:
# a_data_boston_2014_employee_top_100

# %%
#make csv with just the earlier data columns ie 6 of them newdf = df[(df['column_one']>2004) & (df['column_two']==9)]
#AND JUST PICK THE TOP 100 
shortForCsv = salarySorted[["name", "firstName","dept", "salary", "totalSalary","gender"]].head(100)
#df1 = df[['a','b']]
#df1 = df.ix[:,0:2]
shortForCsv['gender'].value_counts()
# Out:
# male      92
# female     8
# Name: gender, dtype: int64

# %%
shortForCsv.head()
# Out:
#                         name firstName                      dept    salary  \
# 6894       Fontana,Gerard T.    Gerard    Boston Fire Department  234578.0
# 6571          Finn,Joseph E.    Joseph    Boston Fire Department  212439.0
# 6230         Evans,William B   William  Boston Police Department  207017.0
# 20819     Walsh,John Francis      John    Boston Fire Department  204893.0
# 8009   Granara,David Richard     David    Boston Fire Department  201219.0
#
#        totalSalary gender
# 6894      286876.0   male
# 6571      212439.0   male
# 6230      207017.0   male
# 20819     219580.0   male
# 8009      217615.0   male

# %% [markdown]
# bring the csv formula lower later..

# %% [markdown]
# I havent done anything about the gender groups yet, I need to make them into M or F and get rid of or
# check the unknowns and mostly's...'

# %%
shortForCsv['gender'].value_counts()
# Out:
# male      92
# female     8
# Name: gender, dtype: int64

# %%
unknowns = shortForCsv[(shortForCsv['gender']== "unknown")]
#MM = shortForCsv[(shortForCsv['gender']== "mostly_male")]
#MF = shortForCsv[(shortForCsv['gender']== "mostly_female")]
print(unknowns) 
#since its a fairly short list Im going to look them up on the intraweb but this is something I should automate or skip those 
#names, or make my own additional filter using social security names?
#i Can also add the ones Ive checked to these lists so they are
# Out:
# Empty DataFrame
# Columns: [name, firstName, dept, salary, totalSalary, gender]
# Index: []

# %% [markdown]
# McCreary - F
# https://www.bostonpublicschools.org/site/default.aspx?PageType=3&ModuleInstanceID=9715&ViewID=7b97f7ed-8e5e-4120-848f-a8b4987d588f&RenderLoc=0&FlexDataID=7541&PageID=4853
#
#  Edouard-Vincent,Marice - F
# https://twitter.com/netsuptb?lang=en
#
# McGovern,Ryan J -- M
# http://www.firehouse.com/news/11252963/after-falling-through-floor-boston-firefighter-thankful-for-minor-injuries
#
# Franklin-Hodge,Jascha -- M
# https://www.boston.gov/departments/innovation-and-technology/jascha-franklin-hodge
#
#   Nee,Kelly A  -- F
# https://www.youtube.com/watch?v=2x7OrSKi_04
#
#  Driscoll,Mary E      Mary  Asst Superintendent-Network A - F
#  https://www.bc.edu/schools/csom/lynchacademy/alumni/2012/Driscoll.html
#
#   Hung,Kelly M     Kelly  Asst Superintendent-Network A  153503.93 -- F
#
#   https://www.bc.edu/schools/csom/lynchacademy/alumni/2014/KHung.html

# %% [markdown]
# NEED TO FIX THE WEB LINK ON THE CHARTS PAGE TO GO TO 2016

# %% [markdown]
# I could look up the mostly and unknowns to confirm their gender -- its just 7 peeps

# %%
shortForCsv.head()
# Out:
#                         name firstName                      dept    salary  \
# 3281             Chang,Tommy     Tommy            Superintendent  259484.0
# 6323         Evans,William B   William  Boston Police Department  221323.0
# 20960     Walsh,John Francis      John    Boston Fire Department  207578.0
# 7000       Fontana,Gerard T.    Gerard    Boston Fire Department  206823.0
# 8095   Granara,David Richard     David    Boston Fire Department  203136.0
#
#        totalSalary gender
# 3281      271734.0   male
# 6323      245305.0   male
# 20960     231707.0   male
# 7000      226244.0   male
# 8095      215264.0   male

# %% [markdown]
# it would be nice to add additioal charts to that page, like for 2016 are the highest paid workers in
# each dept male or female? not sure how to make a simple graph like that, dot matrix?

# %% [markdown]
# it seems like tommy chang is top earner but comes up as superintendent, rather than school system. going to take a look at how they label departments in the larger data set..

# %%
print(shortForCsv["gender"].value_counts()) 
d_2015['gender'].value_counts()
# Out:
# male      92
# female     8
# Name: gender, dtype: int64
# female     10233
# male        9438
# unknown     2060
# andy         171
# Name: gender, dtype: int64

# %% [markdown]
# I'm going to group the schools for the top 100 under Boston Public Schools

# %%
#test = shortForCsv[(shortForCsv['dept']== "Fam & Student Engagemt")]
#test1 = shortForCsv[(shortForCsv['dept']== "Achievement Gap")]
test2 = shortForCsv[(shortForCsv['dept']== "Dpt of Innovation & Technology")]

test2
# Out:
#                        name firstName                            dept  \
# 7053  Franklin-Hodge,Jascha    Jascha  Dpt of Innovation & Technology
#
#         salary  totalSalary gender
# 7053  160832.0     160832.0   male

# %%
shortForCsv.loc[shortForCsv['dept'] == "Asst Superintendent-Network A", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "BPS Special Education", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "Fam & Student Engagemt", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "Achievement Gap", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "Kennedy, EM Health Academy", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "BPS Human Resource Team", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "Superintendent", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "Asst Superintendent-Network G", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "Asst Superintendent-Network B", "dept"] = "Boston Public Schools"
shortForCsv.loc[shortForCsv['dept'] == "BPS Boston Latin", "dept"] = "Boston Public Schools"
#put school chief chang in new school dept group not needed
#shortForCsv.loc[shortForCsv['name'] == "Chang,Tommy", "dept"] = "Boston Public Schools"





shortForCsv["dept"].value_counts()
# Out:
# Boston Fire Department            69
# Boston Police Department          12
# Boston Public Schools             10
# Law Department                     3
# Mayor's Office                     2
# Assessing Department               1
# Chief Operating Officer            1
# Treasury-Treasury Division         1
# Dpt of Innovation & Technology     1
# Name: dept, dtype: int64

# %%
b = d_2015[(d_2015['dept']== "Superintendent")]
b
#could check to see if all these people are in BPS to change the category overall..
# Out:
#                             name            dept  \
# 3228                 Chang,Tommy  Superintendent
# 3878          Connolly,Barbara F  Superintendent
# 4401            Crystal,Danielle  Superintendent
# 4868   Deane-Williams,Barbara A.  Superintendent
# 5091            DePina,Samuel S.  Superintendent
# 5407             Dodd,Melissa P.  Superintendent
# 7562            Giampietro,Erika  Superintendent
# 8382              Hajjar,Carolyn  Superintendent
# 11367               Lee,Edward S  Superintendent
# 12201            MacNeil,Carolyn  Superintendent
# 12523      Marino,Christopher C.  Superintendent
# 13056           McCreary,Makeeba  Superintendent
# 13126           McDonough,John P  Superintendent
# 14435            Muncey,Donna E.  Superintendent
# 14682               Nathan,Linda  Superintendent
# 14869              Nguyen,Long N  Superintendent
# 17070             Ridley,Janelle  Superintendent
# 17240         Robinson,Deandra S  Superintendent
# 19690            Taylor,Albert L  Superintendent
# 20142         Townsend,Norman  E  Superintendent
# 20156          Tran,Buudoan Vinh  Superintendent
# 21248           Wilder,Matthew F  Superintendent
# 21449             Wilson,Ross C.  Superintendent
# 21521               Wong,Bak Fun  Superintendent
#
#                                 title    salary  retroactive     other  \
# 3228                   Superintendent  126523.0          0.0   19250.0
# 3878            Special Assistant (D)  114082.0          0.0    2006.0
# 4401            Deputy Chief of Staff   71727.0          0.0       0.0
# 4868     Senior Deputy Superintendent   86154.0          0.0       0.0
# 5091      Administrator of Operations  154904.0          0.0    2783.0
# 5407                   Chief of Staff   57586.0          0.0   14575.0
# 7562            Special Assistant (E)  130705.0          0.0       0.0
# 8382                   Staff Asst (C)   45660.0          0.0    5574.0
# 11367     Administrator of Operations  153848.0          0.0    5125.0
# 12201                    Ombudsperson  106311.0          0.0    9413.0
# 12523            Manager (D) (non-ac)   29004.0          0.0       0.0
# 13056                  Chief of Staff   80246.0          0.0       0.0
# 13126            Employment Agreement  169263.0          0.0  168477.0
# 14435  Deputy Superintendent-(non-ac)   83692.0          0.0       0.0
# 14682                      Headmaster       0.0          0.0   49234.0
# 14869                     Analyst (C)   36400.0          0.0    2074.0
# 17070            Employment Agreement   79657.0          0.0    1250.0
# 17240                  Staff Asst (B)   10453.0          0.0       0.0
# 19690     Administrator of Operations  155664.0          0.0    2423.0
# 20142     Administrator of Operations  135244.0          0.0       0.0
# 20156             Asst Superintendent   73846.0          0.0       0.0
# 21248            Employment Agreement    9135.0          0.0       0.0
# 21449                Managing Partner  165137.0          0.0    2866.0
# 21521         Academic Superintendent       0.0          0.0   94633.0
#
#        overtime  injured  DETAILS  quinn_education_incentive  totalSalary  \
# 3228        0.0      0.0      0.0                        0.0     145773.0
# 3878        0.0      0.0      0.0                        0.0     116088.0
# 4401        0.0      0.0      0.0                        0.0      71727.0
# 4868        0.0      0.0      0.0                        0.0      86154.0
# 5091        0.0      0.0      0.0                        0.0     157687.0
# 5407        0.0      0.0      0.0                        0.0      72161.0
# 7562        0.0      0.0      0.0                        0.0     130705.0
# 8382        0.0      0.0      0.0                        0.0      51234.0
# 11367       0.0      0.0      0.0                        0.0     158973.0
# 12201   12955.0      0.0      0.0                        0.0     128679.0
# 12523       0.0      0.0      0.0                        0.0      29004.0
# 13056       0.0      0.0      0.0                        0.0      80246.0
# 13126       0.0      0.0      0.0                        0.0     337740.0
# 14435       0.0      0.0      0.0                        0.0      83692.0
# 14682       0.0      0.0      0.0                        0.0      49234.0
# 14869       0.0      0.0      0.0                        0.0      38474.0
# 17070       0.0      0.0      0.0                        0.0      80907.0
# 17240       0.0      0.0      0.0                        0.0      10453.0
# 19690       0.0      0.0      0.0                        0.0     158087.0
# 20142       0.0      0.0      0.0                        0.0     135244.0
# 20156       0.0      0.0      0.0                        0.0      73846.0
# 21248       0.0      0.0      0.0                        0.0       9135.0
# 21449       0.0      0.0      0.0                        0.0     168004.0
# 21521       0.0      0.0      0.0                        0.0      94633.0
#
#       zip_code    firstName   gender
# 3228     02119        Tommy     male
# 3878     02127      Barbara   female
# 4401     02118     Danielle   female
# 4868     02111      Barbara   female
# 5091     02072       Samuel     male
# 5407     02131      Melissa   female
# 7562     02116        Erika   female
# 8382     02189      Carolyn   female
# 11367    02339       Edward     male
# 12201    02132      Carolyn   female
# 12523    02118  Christopher     male
# 13056    02118      Makeeba   female
# 13126    02129         John     male
# 14435    02124        Donna   female
# 14682    02139        Linda   female
# 14869    01604         Long     male
# 17070    01923      Janelle   female
# 17240    02121      Deandra  unknown
# 19690    02148       Albert     male
# 20142    02021       Norman     male
# 20156    02131      Buudoan  unknown
# 21248    02124      Matthew     male
# 21449    02129         Ross     male
# 21521    02111          Bak  unknown

# %%
#Generate histograms using the format df.YOUR_CHOICE_OF_COLUMN_NAME.hist(bins=YOUR_CHOICE_OF_BIN_SIZE)

shortForCsv.salary.hist(bins=20)
plt.xlabel('salaries')
plt.ylabel('Frequency')
plt.title('salaries');

plt.show();
# Out:
#                            name    firstName                        dept  \
# 6894          Fontana,Gerard T.       Gerard      Boston Fire Department
# 6571             Finn,Joseph E.       Joseph      Boston Fire Department
# 6230            Evans,William B      William    Boston Police Department
# 20819        Walsh,John Francis         John      Boston Fire Department
# 8009      Granara,David Richard        David      Boston Fire Department
# 12172          MacKin,Gregory J      Gregory      Boston Fire Department
# 5028               Dempsey,John         John      Boston Fire Department
# 12378            Malone,Scott J        Scott      Boston Fire Department
# 13485          McNeil,Stephen D      Stephen      Boston Fire Department
# 9170          Hocking,Michael E      Michael      Boston Fire Department
# 13426          McMahon,Joseph G       Joseph      Boston Fire Department
# 13719          Merricks,Kirk D.         Kirk    Boston Police Department
# 20271          Tully,Bernard J.      Bernard      Boston Fire Department
# 17664         Ruggere,Michael J      Michael      Boston Fire Department
# 18405        Shea,Bartholomew J  Bartholomew      Boston Fire Department
# 5447         Doherty,Michael J.      Michael      Boston Fire Department
# 20835           Walsh,Martin J.       Martin              Mayor's Office
# 6736     Fleming,Joseph Michael       Joseph      Boston Fire Department
# 3584          Clifford,Peter J.        Peter      Boston Fire Department
# 4159            Costin,Dennis B       Dennis      Boston Fire Department
# 20801          Walsh,David John        David      Boston Fire Department
# 10180            Joseph,David W        David      Boston Fire Department
# 19126        Stallworth,Andre R        Andre      Boston Fire Department
# 2337               Burke,Paul F         Paul      Boston Fire Department
# 8235           Gross,William G.      William    Boston Police Department
# 2548            Cahill,Gerard M       Gerard      Boston Fire Department
# 13126          McDonough,John P         John       Boston Public Schools
# 2634        Calobrisi,Robert J.       Robert      Boston Fire Department
# 1506             Blake,Thomas J       Thomas      Boston Fire Department
# 3130          Celona,Michael O.      Michael      Boston Fire Department
# ...                         ...          ...                         ...
# 8846             Heelen,Brian P        Brian      Boston Fire Department
# 10893                Koh,Daniel       Daniel              Mayor's Office
# 2487             Byrne,Edward F       Edward      Boston Fire Department
# 2232            Buckley,Kevin J        Kevin    Boston Police Department
# 15244   O'Flaherty,Eugene Lloyd       Eugene              Law Department
# 19690           Taylor,Albert L       Albert       Boston Public Schools
# 19800              Teta,Lynne M        Lynne       Boston Public Schools
# 5091           DePina,Samuel S.       Samuel       Boston Public Schools
# 5319          Dillon,Michael P.      Michael      Boston Fire Department
# 17016           Rice,Kimberly A     Kimberly     Chief Operating Officer
# 5969   Edouard-Vincent,Marice M       Marice       Boston Public Schools
# 11367              Lee,Edward S       Edward       Boston Public Schools
# 19165         Staunton,Robert M       Robert      Boston Fire Department
# 2193           Bruynell,James D        James      Boston Fire Department
# 2338               Burke,Paul T         Paul      Boston Fire Department
# 13188   McGillis,Steven Patrick       Steven      Boston Fire Department
# 11779            Long,Gregory P      Gregory    Boston Police Department
# 13469        McNeil,Alexandra M    Alexandra       Boston Public Schools
# 6359           Farrell,Thomas D       Thomas      Boston Fire Department
# 16725           Rakow,Ronald W.       Ronald        Assessing Department
# 19531             Sweeney,David        David  Treasury-Treasury Division
# 2003           Brooks,Joseph F.       Joseph      Boston Fire Department
# 12408           Mandeville,Mark         Mark      Boston Fire Department
# 21062            Weise,Susan M.        Susan              Law Department
# 15677        Papineau,Charles J      Charles      Boston Fire Department
# 5726            Driscoll,Mary E         Mary       Boston Public Schools
# 20272             Tully,Brian P        Brian      Boston Fire Department
# 11989            Luthin,Henry C        Henry              Law Department
# 5647              Dowd,Thomas A       Thomas    Boston Police Department
# 8793              Hayes,Mark P.         Mark    Boston Police Department
#
#          salary  totalSalary  gender
# 6894   234578.0     286876.0    male
# 6571   212439.0     212439.0    male
# 6230   207017.0     207017.0    male
# 20819  204893.0     219580.0    male
# 8009   201219.0     217615.0    male
# 12172  199142.0     258791.0    male
# 5028   194390.0     202106.0    male
# 12378  194323.0     229699.0    male
# 13485  189257.0     222853.0    male
# 9170   187897.0     259790.0    male
# 13426  184848.0     207183.0    male
# 13719  184687.0     185487.0    male
# 20271  182197.0     220674.0    male
# 17664  182197.0     232206.0    male
# 18405  182197.0     243412.0    male
# 5447   182197.0     248004.0    male
# 20835  181731.0     181731.0    male
# 6736   181399.0     224733.0    male
# 3584   179519.0     196032.0    male
# 4159   175947.0     248244.0    male
# 20801  174248.0     195632.0    male
# 10180  174210.0     193873.0    male
# 19126  173666.0     220087.0    male
# 2337   172414.0     217210.0    male
# 8235   171885.0     193751.0    male
# 2548   170124.0     203323.0    male
# 13126  169263.0     337740.0    male
# 2634   169203.0     233845.0    male
# 1506   168024.0     210524.0    male
# 3130   166695.0     193227.0    male
# ...         ...          ...     ...
# 8846   158206.0     177884.0    male
# 10893  157846.0     160477.0    male
# 2487   157417.0     176703.0    male
# 2232   157409.0     204978.0    male
# 15244  155769.0     158159.0    male
# 19690  155664.0     158087.0    male
# 19800  155327.0     156827.0  female
# 5091   154904.0     157687.0    male
# 5319   154666.0     168241.0    male
# 17016  154177.0     154177.0  female
# 5969   153848.0     156271.0  female
# 11367  153848.0     158973.0    male
# 19165  152975.0     169965.0    male
# 2193   152435.0     156453.0    male
# 2338   152013.0     212496.0    male
# 13188  150649.0     162618.0    male
# 11779  150516.0     213668.0    male
# 13469  150119.0     154619.0  female
# 6359   149979.0     173744.0    male
# 16725  149775.0     155322.0    male
# 19531  149423.0     156674.0    male
# 2003   149035.0     170547.0    male
# 12408  149035.0     173047.0    male
# 21062  148748.0     161157.0  female
# 15677  148735.0     184994.0    male
# 5726   148683.0     160183.0  female
# 20272  148506.0     227342.0    male
# 11989  148395.0     155845.0    male
# 5647   147846.0     234894.0    male
# 8793   147846.0     225835.0    male
#
# [100 rows x 6 columns]

# %%
shortForCsv[shortForCsv.gender == "female"].salary.hist(bins=5)
plt.xlabel('salaries')
plt.ylabel('Frequency')
plt.title('salaries');

plt.show();

# %%
shortForCsv[shortForCsv.gender == "male"].salary.hist(bins=5)
plt.xlabel('salaries')
plt.ylabel('Frequency')
plt.title('salaries');

plt.show();

# %%
#d_2015
d_2015[d_2015.gender == "male"].salary.hist(bins=15)
plt.xlabel('salaries')
plt.ylabel('Frequency')
plt.title('salaries');

plt.show();

# %%
#d_2015
d_2015[d_2015.gender == "female"].salary.hist(bins=15)
plt.xlabel('salaries')
plt.ylabel('Frequency')
plt.title('salaries');

plt.show();

# %%
shortForCsv.to_csv("top100_2015", index=False)

# %%
import seaborn as sns
#x = shortForCsv["dept"]
#y = shortForCsv["gender"]
sns.lmplot("dept", "gender", data=shortForCsv, fit_reg=False)
#ax = sns.stripplot(x=shortForCsv["dept"])

#d_2016["firstName"] = y
#d_2016["gender"] = gender
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     751         try:
# --> 752             x = float(x)
#     753         except Exception:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     754             try:
# --> 755                 x = complex(x)
#     756             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     105                 else:
# --> 106                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     107             except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     298     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 299     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     300
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     756             except Exception:
# --> 757                 raise TypeError('Could not convert %s to numeric' % str(x))
#     758     return x
#
# TypeError: Could not convert ... to numeric
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     751         try:
# --> 752             x = float(x)
#     753         except Exception:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     754             try:
# --> 755                 x = complex(x)
#     756             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-235-db8e8d6efaaf> in <module>()
#       2 #x = shortForCsv["dept"]
#       3 #y = shortForCsv["gender"]
# ----> 4 sns.lmplot("dept", "gender", data=shortForCsv, fit_reg=False)
#       5 #ax = sns.stripplot(x=shortForCsv["dept"])
#       6
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/linearmodels.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     566     if sharex:
#     567         for ax in facets.axes.flat:
# --> 568             ax.scatter(data[x], np.ones(len(data)) * data[y].mean()).remove()
#     569
#     570     # Draw the regression plot on each facet
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    5630                                       skipna=skipna)
#    5631         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 5632                             numeric_only=numeric_only)
#    5633
#    5634     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2318                                           'numeric_only.'.format(name))
#    2319             with np.errstate(all='ignore'):
# -> 2320                 return op(delegate, skipna=skipna, **kwds)
#    2321
#    2322         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      48             try:
#      49                 with np.errstate(invalid='ignore'):
# ---> 50                     return f(*args, **kwargs)
#      51             except ValueError as e:
#      52                 # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     107             except Exception:
#     108                 try:
# --> 109                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     110                 except ValueError as e:
#     111                     # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     297         dtype_count = dtype
#     298     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 299     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     300
#     301     if axis is not None and getattr(the_sum, 'ndim', False):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     755                 x = complex(x)
#     756             except Exception:
# --> 757                 raise TypeError('Could not convert %s to numeric' % str(x))
#     758     return x
#     759
#
# TypeError: Could not convert ... to numeric

# %% [markdown]
# Im going to add mostly female and mostly males to females and males respectively, and group androgynous and unknown into one group...maybe ill use them later

# %% [markdown]
# #trying a second gender dectector
# #couldn't geet it to work..
# #import gender_guesser.detector as gender
# import gender_detector.gender_detector as gender2
# #detector = gender_detector('us') # It can also be ar, uk, uy.
# gender2.guess('Marcos') # => 'male'
# #from gender_detector import GenderDetector
# #detector = GenderDetector('us') # It can also be ar, uk, uy.
# #detector.guess('Marcos') # => 'male'

# %%
max(pay_2016.regular)

# %%
min(pay_2016.regular)

# %%
x = pay_2016.iloc[:, 0:1]  #all rows, column 1

# %%
x

# %%
plt.plot(x)
plt.show()

# %%
print x.mean(), x.max(), x.min(), x.mode()

# %%
print birds["speed_2d"].mean(), birds["speed_2d"].max(), birds["speed_2d"].min(), birds["speed_2d"].mode()

# %% [markdown]
# We'll get started by simply plotting the latitude and longitude of a flight
# trajectory for a single bird in a standard two dimensional plot.
# Latitude and longitude are coordinates along the surface of a sphere,
# where a standard 2-D plot is a plane
# so we would expect very strong distortions
# for the flight trajectories.
# This is especially true because the trajectories
# cover a large spatial region.
# We're doing this however, primarily to have a quick way to look at the data
# and develop more intuition about it.
# We'll be doing an actual cartographic projection later in this case study.

# %% [markdown]
# ACCESS ONE COLUMN

# %%
#so grab flight trajectories of single bird 
#birds[bird_name == "Eric"] WRONG! maybe works in np or somewhere?
#makes a boolean
ix = birds.bird_name == "Eric" #for pandas this is how to access column

# %%
#one_bird = birds["latitude"]["longitude", "bird_name"]
#so hes using the ix seems to only grab values if they are True, ie Eric
x, y = birds.longitude[ix], birds.latitude[ix]

# %%
birds.longitude[ix].head()

# %%
plt.subplot(211)
plt.plot(x,y,"ob")
plt.subplot(212)
plt.plot(x,y,) #just shows default is prettier
plt.show()

# %% [markdown]
# plot more birds...

# %%
birds.bird_name.tail(10)

# %% [markdown]
# using unique...

# %%
#but he does something better than this
#ia = birds.bird_name == "Sanne"
#ic = birds.bird_name == "Nico"
names = pd.unique(birds.bird_name)
names

# %%
#having trouble with this, see how he does it below
#he skips making a new dict or list and just puts them in the graph
#latlong = {}
#for i in names:
 #   ix = birds.bird_name == i
  #  x = birds.latitude[ix], 
   # y = birds.longitude[ix]
    #latlong[x] == y

#latlong

# %%
#his example WOW! very cool...
#plt.figure(figsize=(7,7)) # he puts the figure creation outside the loop
#even though  i dont it so blocked it out
for name in names:
    ix = birds.bird_name == name
    x,y = birds.longitude[ix], birds.latitude[ix] #be aware the order you put them in, I had them opposite
    plt.plot(x, y, ".", label=name) #so for the legend to work, have to add the label here! otherwise it just says longitdue...guess the last label available to it
plt.xlabel("Longitude")
plt.ylabel("Latitude") #make sure labels match the data ie x to x and y to latitude
plt.legend(loc="lower right")
plt.show() #im putting this down here and imagine it will work?

# %%
a,b = birds.latitude[ia], birds.longitude[ia]
c,d = birds.latitude[ic], birds.longitude[ic]

# %%
plt.plot(x, y) #this also is quite different from the above, wonder why?
plt.plot(a, b)
plt.plot(c, d)
plt.show()

# %% [markdown]
# * Learn how to examine 2D flight speed of the birds
# * Learn how to deal with data entries that are not numeric
# * The data also contain estimates of two dimensional speeds of the birds.
# That is how fast they were flying on a 2D
# plane that is a local approximation to the curved surface of the earth.
# Let's look at the speed data in a little bit more detail.

# %%
ix = birds.bird_name == "Eric"
speed = birds.speed_2d[ix]
speed

# %% [markdown]
# hist doesnt like it when there are null values so the below
# doesnt run..until they are eliminated..he starts by doing first 10 rows only, so good idea...

# %%
plt.hist(speed[:10]) 
plt.show()

# %% [markdown]
# are there non number objects? ..below are useful tests using numpy

# %%
np.isnan(speed) #i dont see any trues but this is a good way to look
np.isnan(speed).any()#this is much better since it tell us that there is a null value
np.sum(np.isnan(speed)) #sum all the isnans... I got alot more than him??

# %% [markdown]
# turn a list to its opposite with ~

# %%
ind = np.isnan(speed)
ind #ind is a true and false list..the NANs are true
~ind #interesting way to get the mirror opposite of ind, the non nans are now TRUE

# %%
#this looks the same as dropna which is less work! interesting to use that idea thought
ind = np.isnan(speed)
plt.hist(speed[~ind])
plt.show()

# %%
#kind of weird looking though..?
# I used dropna here, 
u = speed.dropna()
plt.hist(u)
plt.show()

# %% [markdown]
# add x label, y label, and make the bins normalized

# %% [markdown]
# ### it looks alot better adding more bins
# * the y axis is normalized, meaning
# that an integral over the histogram would be equal to 1.
# * numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)[source]
# Return evenly spaced numbers over a specified interval.

# %%
ind = np.isnan(speed)
plt.hist(speed[~ind], bins = np.linspace(0,30,20), normed = True)
#i see in docs normed has been deprecated so swapping that with "density",
#which doesnt work in python 2
plt.xlabel("2D Speed (m/s)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Pandas
# provide some planning functions as well,
# although less customizable than PLT plots,
# they readily deal with things like NaNs.
# However you want to make sure that you always
# examine your data carefully and look for the presence of NaNs
# before preparing your plots.
# Let's look at how we would make the histogram using pandas.

# %% [markdown]
# pandas uses the kind and range argument for kind and bin number...all of the nan issue happens under the hood

# %%
birds.speed_2d.plot(kind='hist', range = [0,30]);
plt.xlabel("2D Speed");
plt.show()

# %% [markdown]
# ## * Learn how deal with timestamped data using datetime
# ## * Learn how to measure elapsed time

# %% [markdown]
# year month and day, are all strings, we're going to  convert them into so-called daytime object, that
# supports our arithmetic operations.

# %%
birds.date_time[0:3]

# %%
import datetime

# %%
datetime.datetime.today()

# %%
time_1 = datetime.datetime.today()

# %%
time_2 = datetime.datetime.today()
time_2

# %%
time_2 - time_1

# %% [markdown]
# the above is called a date time time delta object. he said they all end i 00 but mine doesnt, thogh the data set does

# %%
date_str = birds.date_time[0]

# %%
print date_str, type(date_str)

# %% [markdown]
# get rid of the last three characters

# %%
date_str[:-3]

# %% [markdown]
# a long way to strip and prep this
# this has two arguments, the string you are working on, then the format you want for that string -- it is picky though, if you don't peel off those last 3 digits it won't do it!

# %%
datetime.datetime.strptime(date_str[:-3],"%Y-%m-%d %H:%M:%S")

# %% [markdown]
# the ooutput above is a datetime object, we can go over every row and create a new datetime object for each row

# %%
#this was taking along time to run so might be messed up

timestamps = []
done = []
for date in birds.date_time:
    new_date = datetime.datetime.strptime(date_str[:-3],"%Y-%m-%d %H:%M:%S")
    new_time = str(new_date)
    timestamps.append(new_time)

# %%
x = str(timestamps[0])

# %%
x
